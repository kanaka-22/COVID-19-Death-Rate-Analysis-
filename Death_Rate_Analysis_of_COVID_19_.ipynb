# %% [markdown]
# <a href="https://colab.research.google.com/github/kanaka-22/COVID-19-Death-Rate-Analysis-/blob/main/Death_Rate_Analysis_of_COVID_19_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this Data Science study we will analyze the mortality rate of the Covid-19 epidemic using python.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
worldometer_df = pd.read_csv('worldometer_snapshots_April18_to_May18.csv')
worldometer_df
# Out:
#             Date                Country  ...  Serious or Critical  Active Cases
# 0     2020-04-18                    USA  ...              13551.0      631509.0
# 1     2020-04-18                 Russia  ...                  8.0       33423.0
# 2     2020-04-18                  Spain  ...               7371.0       99576.0
# 3     2020-04-18                 Brazil  ...               6634.0       20335.0
# 4     2020-04-18                     UK  ...               1559.0       98409.0
# ...          ...                    ...  ...                  ...           ...
# 6598  2020-05-18              St. Barth  ...                  NaN           0.0
# 6599  2020-05-18         Western Sahara  ...                  NaN           0.0
# 6600  2020-05-18               Anguilla  ...                  NaN           0.0
# 6601  2020-05-18                Lesotho  ...                  NaN           1.0
# 6602  2020-05-18  Saint Pierre Miquelon  ...                  NaN           0.0
#
# [6603 rows x 9 columns]

# %% [markdown]
# To display a sub-table of a specific country :'USA'

# %%
country_name = 'USA'

country_df = worldometer_df.loc[worldometer_df['Country'] == country_name, :].reset_index(drop=True)
country_df
# Out:
#           Date Country  ...  Serious or Critical  Active Cases
# 0   2020-04-18     USA  ...              13551.0      631509.0
# 1   2020-04-19     USA  ...              13566.0      652276.0
# 2   2020-04-20     USA  ...              13951.0      677856.0
# 3   2020-04-21     USA  ...              14016.0      690503.0
# 4   2020-04-22     USA  ...              14016.0      717008.0
# 5   2020-04-23     USA  ...              14997.0      744437.0
# 6   2020-04-24     USA  ...              15097.0      762421.0
# 7   2020-04-25     USA  ...              15110.0      788233.0
# 8   2020-04-26     USA  ...              15143.0      812966.0
# 9   2020-04-27     USA  ...              14186.0      814569.0
# 10  2020-04-28     USA  ...              15298.0      834261.0
# 11  2020-04-29     USA  ...              18671.0      855127.0
# 12  2020-04-30     USA  ...              15226.0      878843.0
# 13  2020-05-01     USA  ...              16481.0      903714.0
# 14  2020-05-02     USA  ...              16139.0      941261.0
# 15  2020-05-03     USA  ...              16139.0      941261.0
# 16  2020-05-04     USA  ...              16050.0      954887.0
# 17  2020-05-05     USA  ...              16179.0      964736.0
# 18  2020-05-06     USA  ...              15827.0      975312.0
# 19  2020-05-07     USA  ...              16995.0      998445.0
# 20  2020-05-08     USA  ...              16978.0     1019567.0
# 21  2020-05-09     USA  ...              16816.0     1029194.0
# 22  2020-05-10     USA  ...              16514.0     1030515.0
# 23  2020-05-11     USA  ...              16484.0     1041814.0
# 24  2020-05-12     USA  ...              16473.0     1028465.0
# 25  2020-05-13     USA  ...              16349.0     1034892.0
# 26  2020-05-14     USA  ...              16240.0     1052654.0
# 27  2020-05-15     USA  ...              16139.0     1068027.0
# 28  2020-05-16     USA  ...              16248.0     1078428.0
# 29  2020-05-17     USA  ...              16355.0     1090297.0
# 30  2020-05-18     USA  ...              16868.0     1101930.0
#
# [31 rows x 9 columns]

# %% [markdown]
# To display a sub-table of a specific country :'Brazil'

# %%
country_name = 'Brazil'

country_df = worldometer_df.loc[worldometer_df['Country'] == country_name, :].reset_index(drop=True)
country_df
# Out:
#           Date Country  ...  Serious or Critical  Active Cases
# 0   2020-04-18  Brazil  ...               6634.0       20335.0
# 1   2020-04-19  Brazil  ...               6634.0       14062.0
# 2   2020-04-20  Brazil  ...               7919.0       16026.0
# 3   2020-04-21  Brazil  ...               8318.0       16013.0
# 4   2020-04-22  Brazil  ...               8318.0       17533.0
# 5   2020-04-23  Brazil  ...               8318.0       19606.0
# 6   2020-04-24  Brazil  ...               8318.0       21670.0
# 7   2020-04-25  Brazil  ...               8318.0       25991.0
# 8   2020-04-26  Brazil  ...               8318.0       28436.0
# 9   2020-04-27  Brazil  ...               8318.0       30816.0
# 10  2020-04-28  Brazil  ...               8318.0       35292.0
# 11  2020-04-29  Brazil  ...               8318.0       39718.0
# 12  2020-04-30  Brazil  ...               8318.0       43544.0
# 13  2020-05-01  Brazil  ...               8318.0       47660.0
# 14  2020-05-02  Brazil  ...               8318.0       51131.0
# 15  2020-05-03  Brazil  ...               8318.0       51131.0
# 16  2020-05-04  Brazil  ...               8318.0       55108.0
# 17  2020-05-05  Brazil  ...               8318.0       58573.0
# 18  2020-05-06  Brazil  ...               8318.0       66653.0
# 19  2020-05-07  Brazil  ...               8318.0       71155.0
# 20  2020-05-08  Brazil  ...               8318.0       76603.0
# 21  2020-05-09  Brazil  ...               8318.0       83720.0
# 22  2020-05-10  Brazil  ...               8318.0       86619.0
# 23  2020-05-11  Brazil  ...               8318.0       90134.0
# 24  2020-05-12  Brazil  ...               8318.0       92601.0
# 25  2020-05-13  Brazil  ...               8318.0       97575.0
# 26  2020-05-14  Brazil  ...               8318.0      109446.0
# 27  2020-05-15  Brazil  ...               8318.0      118436.0
# 28  2020-05-16  Brazil  ...               8318.0      127837.0
# 29  2020-05-17  Brazil  ...               8318.0      130840.0
# 30  2020-05-18  Brazil  ...               8318.0      138056.0
#
# [31 rows x 9 columns]

# %% [markdown]
# display a sub-table of a specific date :'18/04/2020'

# %%
selected_date = datetime.strptime('18/04/2020', '%d/%m/%Y')
selected_date_df = worldometer_df.loc[worldometer_df['Date'] == selected_date.strftime('%Y-%m-%d'), :].reset_index(drop=True)
selected_date_df
# Out:
#            Date                Country  ...  Serious or Critical  Active Cases
# 0    2020-04-18                    USA  ...              13551.0      631509.0
# 1    2020-04-18                 Russia  ...                  8.0       33423.0
# 2    2020-04-18                  Spain  ...               7371.0       99576.0
# 3    2020-04-18                 Brazil  ...               6634.0       20335.0
# 4    2020-04-18                     UK  ...               1559.0       98409.0
# ..          ...                    ...  ...                  ...           ...
# 208  2020-04-18              St. Barth  ...                  NaN           1.0
# 209  2020-04-18         Western Sahara  ...                  NaN           6.0
# 210  2020-04-18               Anguilla  ...                  NaN           2.0
# 211  2020-04-18                Lesotho  ...                  NaN           NaN
# 212  2020-04-18  Saint Pierre Miquelon  ...                  NaN           1.0
#
# [213 rows x 9 columns]

# %% [markdown]
# display a sub-table of a specific date :'18/04/2020'

# %%
last_date = datetime.strptime('18/04/2020', '%d/%m/%Y')

last_date_df = worldometer_df.loc[worldometer_df['Date'] == last_date.strftime('%Y-%m-%d'), :].reset_index(drop=True)
last_date_df
# Out:
#            Date                Country  ...  Serious or Critical  Active Cases
# 0    2020-04-18                    USA  ...              13551.0      631509.0
# 1    2020-04-18                 Russia  ...                  8.0       33423.0
# 2    2020-04-18                  Spain  ...               7371.0       99576.0
# 3    2020-04-18                 Brazil  ...               6634.0       20335.0
# 4    2020-04-18                     UK  ...               1559.0       98409.0
# ..          ...                    ...  ...                  ...           ...
# 208  2020-04-18              St. Barth  ...                  NaN           1.0
# 209  2020-04-18         Western Sahara  ...                  NaN           6.0
# 210  2020-04-18               Anguilla  ...                  NaN           2.0
# 211  2020-04-18                Lesotho  ...                  NaN           NaN
# 212  2020-04-18  Saint Pierre Miquelon  ...                  NaN           1.0
#
# [213 rows x 9 columns]

# %% [markdown]
# calculate the naive death rate for each country and show histogram :

# %%
last_date_df['Case Fatality Ratio'] = last_date_df['Total Deaths'] / last_date_df['Total Cases']
plt.figure(figsize=(12,8))
plt.hist(100 * np.array(last_date_df['Case Fatality Ratio']), bins=np.arange(35))
plt.xlabel('Death Rate (%)', fontsize=16)
plt.ylabel('Number of Countries', fontsize=16)
plt.title('Histogram of Death Rates for various Countries', fontsize=18)
plt.show()

# %% [markdown]
# Filter countries with fewer cases:

# %%
min_number_of_cases = 1000
greatly_affected_df = last_date_df.loc[last_date_df['Total Cases'] > min_number_of_cases,:]
plt.figure(figsize=(12,8))
plt.hist(100 * np.array(greatly_affected_df['Case Fatality Ratio']), bins=np.arange(35))
plt.xlabel('Death Rate (%)', fontsize=16)
plt.ylabel('Number of Countries', fontsize=16)
plt.title('Histogram of Death Rates for various Countries', fontsize=18)
plt.show()

# %% [markdown]
# Scatter Plot Using Analysis of Death rate

# %%
last_date_df['Num Tests per Positive Case'] = last_date_df['Total Tests'] / last_date_df['Total Cases']

min_number_of_cases = 1000
greatly_affected_df = last_date_df.loc[last_date_df['Total Cases'] > min_number_of_cases,:]

x_axis_limit = 80

death_rate_percent = 100 * np.array(greatly_affected_df['Case Fatality Ratio'])
num_test_per_positive = np.array(greatly_affected_df['Num Tests per Positive Case'])
num_test_per_positive[num_test_per_positive > x_axis_limit] = x_axis_limit
total_num_deaths = np.array(greatly_affected_df['Total Deaths'])
population = np.array(greatly_affected_df['Population'])

# %%
plt.figure(figsize=(16,12))
plt.scatter(x=num_test_per_positive, y=death_rate_percent, 
            s=0.5*np.power(np.log(1+population),2), 
            c=np.log10(1+total_num_deaths))
plt.colorbar()
plt.ylabel('Death Rate (%)', fontsize=16)
plt.xlabel('Number of Tests per Positive Case', fontsize=16)
plt.title('Death Rate as function of Testing Quality', fontsize=18)
plt.xlim(-1, x_axis_limit + 12)
plt.ylim(-0.2,17)
# Out:
# (-0.2, 17.0)

# %% [markdown]
# The cutoff for good testing country is 75 test positive cases and 100 test Positive cases

# %%
good_testing_threshold = 75
good_testing_df = greatly_affected_df.loc[greatly_affected_df['Num Tests per Positive Case'] > good_testing_threshold,:]
good_testing_df
# Out:
#           Date     Country  ...  Case Fatality Ratio  Num Tests per Positive Case
# 28  2020-04-18         UAE  ...             0.005871                   121.707394
# 72  2020-04-18  Uzbekistan  ...             0.003356                    91.275168
# 98  2020-04-18   Hong Kong  ...             0.003906                   128.697266
#
# [3 rows x 11 columns]

# %%
estimated_death_rate_percent = 100 * good_testing_df['Total Deaths'].sum() / good_testing_df['Total Cases'].sum()
print('Death Rate only for "good testing countries" is %.2f%s' %(estimated_death_rate_percent,'%'))
# Out:
# Death Rate only for "good testing countries" is 0.52%

# %%
good_testing_threshold = 100
good_testing_df = greatly_affected_df.loc[greatly_affected_df['Num Tests per Positive Case'] > good_testing_threshold,:]
good_testing_df
# Out:
#           Date    Country  ...  Case Fatality Ratio  Num Tests per Positive Case
# 28  2020-04-18        UAE  ...             0.005871                   121.707394
# 98  2020-04-18  Hong Kong  ...             0.003906                   128.697266
#
# [2 rows x 11 columns]

# %%
estimated_death_rate_percent = 100 * good_testing_df['Total Deaths'].sum() / good_testing_df['Total Cases'].sum()
print('Death Rate only for "good testing countries" is %.2f%s' %(estimated_death_rate_percent,'%'))
# Out:
# Death Rate only for "good testing countries" is 0.56%
